# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing

df = pd.read_csv('motility_features.csv')

# converts valid date entries to date, changes non-valid entries (. and nan) to NaT
#df["DATE"] = pd.to_datetime(df["DATE"], infer_datetime_format=True, errors='coerce')

df.head()
# Out:
#      VAP    VSL    VCL  ALH   BCF  STR  LIN BLAST_D8
# 0  112.2   94.5  212.3  9.0  34.2   82   44   33.333
# 1  123.7  103.7  218.5  9.4  29.8   82   48   16.049
# 2   96.4   81.1  181.9  8.2  28.4   82   47   20.253
# 3   55.5   48.8   84.8  6.5  29.9   90   69   27.027
# 4  104.5   92.1  181.4  6.8  40.1   86   51   39.024

# %%
df = df.char.replace("-", np.nan)
df = df[['STR']].values.astype(float)
df = df[['LIN']].values.astype(float)
df.cov()
# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
x_scaled = min_max_scaler.fit_transform(df)

# Run the normalizer on the dataframe
df_normalized = pd.DataFrame(x_scaled)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-5d68c916a8ce> in <module>
# ----> 1 df = df.char.replace("-", np.nan)
#       2 df = df[['STR']].values.astype(float)
#       3 df = df[['LIN']].values.astype(float)
#       4 df.cov()
#       5 # Create a minimum and maximum processor object
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'char'

# %%
df.cov()
# Out:
#             VAP         VSL         VCL        ALH        BCF        STR  \
# VAP  298.556027  293.060750  368.402134  -1.947169  12.805793  25.860796
# VSL  293.060750  318.529902  280.596996  -8.905841  29.391008  55.198924
# VCL  368.402134  280.596996  803.867049  22.859650 -30.965716 -46.926532
# ALH   -1.947169   -8.905841   22.859650  19.596660  -6.208647  -7.213064
# BCF   12.805793   29.391008  -30.965716  -6.208647  25.674933  19.113720
# STR   25.860796   55.198924  -46.926532  -7.213064  19.113720  33.105960
# LIN   38.712118   77.814155  -99.416756 -10.710836  25.849657  45.034045
#
#            LIN
# VAP  38.712118
# VSL  77.814155
# VCL -99.416756
# ALH -10.710836
# BCF  25.849657
# STR  45.034045
# LIN  77.292526

# %%
df_normalized.cov()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.033645  0.036472  0.025150 -0.000371  0.005091  0.009151  0.008934
# 1  0.036472  0.043778  0.021155 -0.001874  0.012905  0.021571  0.019831
# 2  0.025150  0.021155  0.033245  0.002639 -0.007458 -0.010059 -0.013899
# 3 -0.000371 -0.001874  0.002639  0.006316 -0.004175 -0.004317 -0.004180
# 4  0.005091  0.012905 -0.007458 -0.004175  0.036015  0.023862  0.021047
# 5  0.009151  0.021571 -0.010059 -0.004317  0.023862  0.036784  0.032633
# 6  0.008934  0.019831 -0.013899 -0.004180  0.021047  0.032633  0.036528
# 7 -0.002678 -0.000920 -0.004241 -0.001839  0.001021  0.004201  0.002366
#
#           7
# 0 -0.002678
# 1 -0.000920
# 2 -0.004241
# 3 -0.001839
# 4  0.001021
# 5  0.004201
# 6  0.002366
# 7  0.042933

# %%
df_full = pd.read_csv('motility_features.csv')
df_full = df_full.replace("-", np.nan)
df_full = df_full.dropna()

# %%
brate = pd.to_numeric(df_full["BLAST_D8"],errors='coerce')

df_full.loc[brate > 25, "class"] = "High"
df_full.loc[brate < 25, "class"] = "Low"
df_full
# Out:
#        VAP    VSL    VCL   ALH   BCF  STR  LIN BLAST_D8 class
# 0    112.2   94.5  212.3   9.0  34.2   82   44   33.333  High
# 1    123.7  103.7  218.5   9.4  29.8   82   48   16.049   Low
# 2     96.4   81.1  181.9   8.2  28.4   82   47   20.253   Low
# 3     55.5   48.8   84.8   6.5  29.9   90   69   27.027  High
# 4    104.5   92.1  181.4   6.8  40.1   86   51   39.024  High
# 5     97.1   80.5  175.7   8.5  26.6   82   47   25.806  High
# 6    110.8  100.4  179.4   8.3  35.7   90   60   34.247  High
# 7    112.4   97.5  192.8   8.7  31.7   85   51   23.611   Low
# 8    114.0  100.5  167.7   5.4  39.7   87   61   23.529   Low
# 9    105.5   98.3  162.8   5.0  41.3   92   64   35.211  High
# 10   125.9  111.6  216.1   8.7  33.5   87   52   34.328  High
# 11    83.7   58.6  169.5  11.9  23.6   69   36    24.59   Low
# 12   121.6  103.2  223.0  10.3  31.9   82   46   27.692  High
# 13    97.7   90.2  143.0   4.1  40.6   90   64   24.638   Low
# ...
